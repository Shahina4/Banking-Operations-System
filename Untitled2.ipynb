# %%
list1 = [1,2,3]
list2 = [7,8,9]

# %%
addition = [list1[i]+list2[i] for i in range(3)]
print(f"Addition of {list1} and {list2} is {addition}")
# Out:
# Addition of [1, 2, 3] and [7, 8, 9] is [8, 10, 12]

# %%
addition = [list1[i]+list2[j] for i in range(len(list1)) for j in range(len(list2))]
print(addition)
# Out:
# [8, 9, 10, 9, 10, 11, 10, 11, 12]
