# %%
def pyramid_pattern(n):
    for i in range(1, n+1):
        for j in range(n-1):
            print(" ", end=" ")
        for k in range(1, i+1):
            print("*", end=" ")
        print("\n")
pyramid_pattern(5)
# Out:
#         *
#
#         * *
#
#         * * *
#
#         * * * *
#
#         * * * * *

# %%
def pyramid_pattern(n):
    for i in range(1, n+1):
        #for j in range(n-1):
        #    print(" ", end=" ")
        for k in range(1, i+1):
            print("*", end=" ")
        print("\n")
pyramid_pattern(5)
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *

# %%
def pyramid_pattern(n):
    for i in range(1, n+1):
        for j in range(n-1):
            print(" ", end=" ")
            for k in range(1, i+1):
                print("*", end=" ")
        print("\n")
pyramid_pattern(5)
# Out:
#   *   *   *   *
#
#   * *   * *   * *   * *
#
#   * * *   * * *   * * *   * * *
#
#   * * * *   * * * *   * * * *   * * * *
#
#   * * * * *   * * * * *   * * * * *   * * * * *
