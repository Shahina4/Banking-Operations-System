# %%
word=input("Enter a string")
rev_str=""
for i in range(-1,-len(word)-1,-1):
    rev_str+=word[i]
print(rev_str)
# Out:
# Enter a string hello
# olleh

# %%
word=input("Enter a string")
def isPalindrome(word):
    return word == word[::-1]
if isPalindrome(word):
    print(f"{word} is a palindrome string")
else:
    print(f"{word} is not a palindrome string")
# Out:
# Enter a string rever
# rever is a palindrome string

# %%
word=input("Enter a string")
def isPalindrome(word):
    return word == word[::-1]
if isPalindrome(word):
    print(f"{word} is a palindrome string")
else:
    print(f"{word} is not a palindrome string")
# Out:
# Enter a string reverse
# reverse is not a palindrome string

# %%
num=int(input("Enter a number:"))
def factorial(num):
    if num==0 or num==1:
        return 1
    if num>1:
        return num*factorial(num-1)
print(factorial(num))
# Out:
# Enter a number: 5
# 120

# %%
number=int(input("Enter a number:"))
res=1
if number==0 or number==1:
    res=1
if number>1:
    for i in range(1,number+1):
        res*=i
print(f"Factorial of {number} is {res}")
# Out:
# Enter a number: 5
# Factorial of 5 is 120

# %%
n=int(input("Enter the number of terms:"))
fib = [0,1]
for i in range(n-2):
    fib.append(fib[-1]+fib[-2])
print(fib)
# Out:
# Enter the number of terms: 5
# [0, 1, 1, 2, 3]

# %%
myList=[5,1,8,2,3,7,4,6]
print(f"Largest number in a list:{max(myList)}")
print(f"Smallest number in a list:{min(myList)}")
# Out:
# Largest number in a list:8
# Smallest number in a list:1

# %%
myList=[8,1,2,3,4,5,1,1,2,3,4]
for i in set(myList):
    print(f"Frequency of {i} is {myList.count(i)}")
# Out:
# Frequency of 1 is 3
# Frequency of 2 is 2
# Frequency of 3 is 2
# Frequency of 4 is 2
# Frequency of 5 is 1
# Frequency of 8 is 1

# %%
newList=[1,2,6,4,3,1,5,6,4,2,8]
print(list(set(newList)))
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
number=int(input("Enter a number:"))
res="yes"
if number<=1:
    res="no"
else:
    for i in range(2,int(number**0.5)+1):
        if number%i==0:
            res='no'
if(res=='yes'):
    print(f"{number} is a prime number")
else:
    print(f"{number} is not a prime number")
# Out:
# Enter a number: 7
# 7 is a prime number

# %%
num=int(input("Enter a number:"))
given=num
sum=0
while num>0:
    temp=num%10
    sum+=temp
    num=num//10
print(f"Sum of digits of {given} is {sum}")
# Out:
# Enter a number: 345
# Sum of digits of 345 is 12

# %%
var1=input("Enter first value")
var2=input("Enter second value")
var1,var2=var2,var1
print(var1)
print(var2)
# Out:
# Enter first value hi
# Enter second value 2
# 2
# hi
