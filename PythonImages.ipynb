# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (10.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
peas = Image.open('Peas.jpg')

# %%
type(peas)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
peas
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x180>

# %%
peas.size
# Out:
# (288, 180)

# %%
peas.filename
# Out:
# 'C:\\Users\\HP\\Desktop\\PythonLearning\\Peas.jpg'

# %%
peas.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
peas.crop((100,25,1000,800))
# Out:
# <PIL.Image.Image image mode=RGB size=900x775>

# %%
dog = Image.open('Dog.png')

# %%
dog
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1466x842>

# %%
type(dog)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
dog.size
# Out:
# (1466, 842)

# %%
x=0
y=0

w=1600/3
h=1200/10

# %%
dog.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=533x120>

# %%
dog.crop(x,y,w,h) #Need to pass this inside tuple only
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dog.crop(x,y,w,h)
#
# TypeError: Image.crop() takes from 1 to 2 positional arguments but 5 were given

# %%
#Bottom of the image

x = 100
y = 450

w = 1600/3
h=1200

# %%
dog.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=513x1110>
