# %% [markdown]
# Tuples are very similar to lists. However they have one key difference- Immutability
# Once an element is inside a tuple, it cannot be reassigned
# Tuples use: () paranthesis
# methods: type(), len(), count(), index()

# %%
t=(1,2,3)

# %%
my_list=[1,2,3]

# %%
type(t)
# Out:
# tuple

# %%
type(my_list)
# Out:
# list

# %%
len(t)
# Out:
# 3

# %%
len(my_list)
# Out:
# 3

# %%
my_list[0]='one'

# %%
my_list  #List : mutable
# Out:
# ['one', 2, 3]

# %%
t[0]='one' #Tuple : immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t[0]='one'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t

# %%
t=('a','a','b')

# %%
t.count('c') #count also works for list
# Out:
# 0

# %%
t.count('a')
# Out:
# 2

# %%
#index() returns first index value of the instance of an item
t.index('a') #index() also works for list
# Out:
# 0

# %%
t=(1,1,1,1,2,3,4,5,6,7)

# %%
t.count(1)
# Out:
# 4

# %%
#practice
t=(1,2,3,4,'Hi',34.5,True) #can pass multiple diff values

# %%
t
# Out:
# (1, 2, 3, 4, 'Hi', 34.5, True)

# %%
t.sort()  #Immutability once we store the values in tuple we can't even change it for sorting
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
t[4].upper()
# Out:
# 'HI'

# %%
temp=t[4].upper()

# %%
temp
# Out:
# 'HI'

# %%
t[4]
# Out:
# 'Hi'

# %%
t = (7,2,9,1,0,5,6)

# %%
sorted(t)
# Out:
# [0, 1, 2, 5, 6, 7, 9]

# %%
tuple(sorted(t))
# Out:
# (0, 1, 2, 5, 6, 7, 9)
