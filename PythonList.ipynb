# %% [markdown]
# A list a data structure in python that is a mutable, or changeable, ordered sequence of elements. Each element or value that
# is inside of a list is called an item.
# #Methods: append(), pop(), type(), sort(), count(), index(), len()

# %%
my_list=[1,2,3] #[30,51,64]    #my_list --> snake case  and myList --> camel case

# %%
print(my_list)  #my_listItems: using both snakecase&camelcase in a variableName is not recommended in corporate terminology
# Out:
# [1, 2, 3]

# %%
my_list           #As discussed earlier a space is automatically generated by , in python
# Out:
# [1, 2, 3]

# %%
my_list=[30,51,64]

# %%
my_list
# Out:
# [30, 51, 64]

# %%
myList=[10,2.5,True,"List String"]   #list can contain different type of items

# %%
myList
# Out:
# [10, 2.5, True, 'List String']

# %% [markdown]
# List Indexing

# %%
my_list1 = ["string",2,30.555,87,4658,34] #elements with different datatypes are allowed in a list.

# %%
len(my_list1) #length   Here, len is a function/method used for getting length of my_list1
# Out:
# 6

# %%
my_list1[0]     #index represents an address of an item in a list and it always starts from 0
# Out:
# 'string'

# %%
print(my_list1[4])#Jupyter notebook displays both internal execution&output part of python 
    # i.e, Takes value/variable/expression as In[..] and displays output in Out[..] --> Internal execution of python code
    #  and Takes print() as In[..] and displays output without mentioning Out[..]   --> Actual Output of python code         
 #while other IDEs only display output through print() but doesn't display execution part.
# Out:
# 4658

# %%
print(my_list1[6]) #index value exceeding list size
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(my_list1[6])
#
# IndexError: list index out of range

# %%
print(my_list1[-6])     #reverse indexing starts from -1 for last item

# %%
print(my_list1[-7]) #index value exceeding list size

# %%
my_list=['one','two','three',85,963,741,'four']
newList=[10,20,30,40,50]

# %% [markdown]
# List Indexing using start:end

# %%
newList[1:]
# Out:
# [20, 30, 40, 50]

# %%
newList[1:3] # start, ..,..,end-1 : excludes or doesn't consider index's end position
# Out:
# [20, 30]

# %%
#if end value>=len(list) then it displays list from start position to len(list)-1 position & doesn't consider the rest.
newList[1:5]
# Out:
# [20, 30, 40, 50]

# %%
newList[1:10]
# Out:
# [20, 30, 40, 50]

# %%
10 + 20 # both are integers
# Out:
# 30

# %%
'10'+20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 '10'+20
#
# TypeError: can only concatenate str (not "int") to str

# %%
'string'+my_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 'string'+my_list
#
# TypeError: can only concatenate str (not "list") to str

# %%
'Hello'+'World'

# %%
my_list+my_list #concatenation (joining to 2 strings)
# Out:
# ['one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  'one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four']

# %%
concatList = my_list + newList   
#Easiness of python i.e, storing output of two lists as a single list in a variable for future usage.

# %%
print(concatList)
# Out:
# ['one', 'two', 'three', 85, 963, 741, 'four', 10, 20, 30, 40, 50]

# %%
#List Slicing   #13/5/25 typed in

# %%
my_list=['one', 'two', 'three', 85, 963, 741, 'four']

# %%
my_list[0:] #list slicing
# Out:
# ['one', 'two', 'three', 85, 963, 741, 'four']

# %%
my_list[0:3] # list slicing
# Out:
# ['one', 'two', 'three']

# %%
newList=['six',7,'eight',9]

# %%
newList
# Out:
# ['six', 7, 'eight', 9]

# %%
another_list=my_list+newList

# %%
another_list[2:7]
# Out:
# ['three', 85, 963, 741, 'four']

# %%
x=10

# %%
newVar=another_list+x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 newVar=another_list+x
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# List Concatenation

# %%
my_list+another_list
# Out:
# ['one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  'one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  'six',
#  7,
#  'eight',
#  9]

# %%
newList=my_list+another_list

# %%
newList[-4]=66   #mutable --> it is replacing with old val 'six' but not overriding

# %%
newList
# Out:
# ['one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  'one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  66,
#  7,
#  'eight',
#  9]

# %%
#append() method is used to add new element at the end of the list. This permanently changes the list.
#append() can add duplicate/repeated values
newList.append('newValue')

# %%
newList
# Out:
# ['one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  'one',
#  'two',
#  'three',
#  85,
#  963,
#  741,
#  'four',
#  66,
#  7,
#  'eight',
#  9,
#  'newValue']

# %%
#pop() method is used to remove the last element from the list. Reverse indexing also works for list
#pop() method takes only one index for removing specific element.  
#It cmpletely extract the value from list and display in exec part but not in output part.
newList.pop(-2)
# Out:
# 9

# %%
myList1=[1,2,3,4,5]

# %%
myList2=[10,'twenty',30]

# %%
myList1.append(myList2)

# %%
myList1
# Out:
# [1, 2, 3, 4, 5, [10, 'twenty', 30]]

# %%
print(myList1[-1][-2])
# Out:
# twenty

# %%
myList1
# Out:
# [1, 2, 3, 4, 5, [10, 'twenty', 30]]

# %%
myList1[5][-2]
# Out:
# 'twenty'

# %%
#By default pop() the last element. However, we can also pass the index number as parameter to remove a particular item
#we can store popped value in new variable for reuse or future use.
poppedElement=newList.pop(0)

# %%
fruits = ['apple', 'mango', 'orange', 'potato', 'grapes']
veg=['carrot', 'tomato', 'onion']

# %%
tempVeg = fruits.pop(-2)   
#Storing popped item 'potato' in tempVeg. For adding 'potato' to veg list from fruits list

# %%
tempVeg
# Out:
# 'potato'

# %%
veg.append(tempVeg)

# %%
veg
# Out:
# ['carrot', 'tomato', 'onion', 'potato']

# %%
fruits
# Out:
# ['apple', 'mango', 'orange', 'grapes']

# %%
x=10          #int
y=20.36       #float
z='besant'    #str
a=[1,2,3]     #list
b=True        #bool

# %%
type(b)
# Out:
# bool

# %%
my_newList=[10,20,30,40,50,60,70]

# %%
my_newList.append("Hi")

# %%
my_newList
# Out:
# [10, 20, 30, 40, 50, 60, 70, 'Hi']

# %%
my_newList.pop()
# Out:
# 'Hi'

# %%
my_newList
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
#Sorting the list in Python
newList=['A','h','r','a','c','b','z','Z','X',4,56,7,7,8,5,4,2]
numList=[6,8,9,1,5,4]

# %%
newList
# Out:
# ['A', 'h', 'r', 'a', 'c', 'b', 'z', 'Z', 'X', 4, 56, 7, 7, 8, 5, 4, 2]

# %%
numList
# Out:
# [6, 8, 9, 1, 5, 4]

# %%
newList.sort() #sort() will sort the elements and kept the sorted list in it's variable itself
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 newList.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
print(newList)
# Out:
# ['A', 'X', 'Z', 'a', 'b', 'c', 'h', 'r', 'z', 4, 56, 7, 7, 8, 5, 4, 2]

# %%
var=numList.sort()

# %%
type(var)
# Out:
# NoneType

# %%
type(numList)
# Out:
# list

# %%
print(numList)
# Out:
# [1, 4, 5, 6, 8, 9]

# %%
#Incase of sorting, new variable cannot store a sorted list of values. It will sorts and stores in a variable itself automatically. 
numList.sort()

# %%
numList
# Out:
# [1, 4, 5, 6, 8, 9]

# %%
#Below code is not possible. newList.sort() gets error itself
mySortedList=newList.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 2
#       1 #Below code is not possible. newList.sort() gets error itself
# ----> 2 mySortedList=newList.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
type(mySortedList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 type(mySortedList)
#
# NameError: name 'mySortedList' is not defined

# %%
list=['a','a','b']

# %%
list.count('a')
# Out:
# 2

# %%
list.index('a')
# Out:
# 0

# %%
#Practice
l1=[1,2,3,3,4,5]

# %%
l1.pop(2)
# Out:
# 3

# %%
l1.pop(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 l1.pop(2,3)
#
# TypeError: pop expected at most 1 argument, got 2

# %%
l1.append(6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 l1.append(6,7)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1.append(6)

# %%
l1
# Out:
# [1, 2, 3, 4, 5]
