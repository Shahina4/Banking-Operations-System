# %%
OPERATORS IN PYTHON

# %%
Arithmetic Operators

# %%
a,b=5,3

# %%
a+b #addition operator
# Out:
# 8

# %%
a-b #subtraction operator
# Out:
# 2

# %%
a*b #Multiplication operator
# Out:
# 15

# %%
a/b #division operator
# Out:
# 1.6666666666666667

# %%
a%b #modulus operator
# Out:
# 2

# %%
a//b #floor division operator
# Out:
# 1

# %%
a**b #exponential operator
# Out:
# 125

# %%
Relational/ Comparison Operators

# %%
a!=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
Unary Operator

# %%
+a
# Out:
# 5

# %%
-a
# Out:
# -5

# %%
+b
# Out:
# 3

# %%
-b
# Out:
# -3

# %%
Assignment Operators

# %%
a=5

# %%
a+=1

# %%
a
# Out:
# 6

# %%
a-=1

# %%
a
# Out:
# 5

# %%
a*=1

# %%
a
# Out:
# 5

# %%
a/=1

# %%
a
# Out:
# 5.0

# %%
a//=1

# %%
a
# Out:
# 5.0

# %%
a%=1

# %%
a
# Out:
# 0.0

# %%
a**=1

# %%
a
# Out:
# 0.0

# %%
Bitwise Operators

# %%
a=5 b=3
# Out:
#   File "<ipython-input-34-7d04abf1ced3>", line 1
#     a=5 b=3
#         ^
# SyntaxError: invalid syntax

# %%
a=5
b=3

# %%
a|b
# Out:
# 7

# %%
a&b
# Out:
# 1

# %%
a^b
# Out:
# 6

# %%
~a
# Out:
# -6

# %%
~b
# Out:
# -4

# %%
~5
# Out:
# -6

# %%
a<<2
# Out:
# 20

# %%
b<<3
# Out:
# 24

# %%
a>>2
# Out:
# 1

# %%
b>>3
# Out:
# 0

# %%
Logical Operators

# %%
(a>b)&&(a<b) #In python, logical operator doesn't use symbolized operators instead it uses keywords and, or, not
# Out:
#   File "<ipython-input-46-b23cfd653daf>", line 1
#     (a>b)&&(a<b) #In python, logical operator doesn't use symbolized operators instead it uses keywords and, or, not
#           ^
# SyntaxError: invalid syntax

# %%
(a<b)||(a>b)
# Out:
#   File "<ipython-input-47-8dffe39f88be>", line 1
#     (a<b)||(a>b)
#           ^
# SyntaxError: invalid syntax

# %%
(a>b) and (a<b)
# Out:
# False

# %%
(a<b) or (a>b)
# Out:
# True

# %%
not (a<b)
# Out:
# True

# %%
Membership Operators#Will be used for sequence of elements(list, tuple, dictionary)

# %%
myList = [1,2,3,4,5]

# %%
2 in myList
# Out:
# True

# %%
2 not in myList
# Out:
# False

# %%
Identity Operators

# %%
a=5
b=6

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True
