# %%
10+20
# Out:
# 30

# %%
50-30
# Out:
# 20

# %%
76*2
# Out:
# 152

# %%
67/2
# Out:
# 33.5

# %%
67%2
# Out:
# 1

# %%
50-36
# Out:
# 14

# %%
x=50 #int datatype

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Hello World')
# Out:
#   File "<ipython-input-10-f1fa627f45a2>", line 1
#     print("Hello World')
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
#The below code is fix of the above code
print("Hello World")
# Out:
# Hello World

# %%
#The below code is fix of the above code
print('Hello World')
# Out:
# Hello World

# %%
print("50")
# Out:
# 50

# %%
print("x")
# Out:
# x

# %%
print(x)
# Out:
# 50

# %%
print("x = ")
print(x)
# Out:
# x =
# 50

# %%
print("x = "x)
# Out:
#   File "<ipython-input-18-72b9d7a585e2>", line 1
#     print("x = "x)
#                 ^
# SyntaxError: invalid syntax

# %%
print("x = ",x)
# Out:
# x =  50

# %%
print("x =",x)
# Out:
# x = 50

# %%
y=50.555 #float datatype

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d9183e048de3> in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %%
y=50.555

# %%
print(y)
# Out:
# 50.555

# %%
z = "Besant Technologies" #str datatype

# %%
print(z)
# Out:
# Besant Technologies

# %%
#boolean value : first letter should be capital letter
a = True #boolean datatype

# %%
print(a)
# Out:
# True

# %%
a = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c100e6034b0a> in <module>
# ----> 1 a = true
#
# NameError: name 'true' is not defined

# %%
a = False

# %%
print(a)
# Out:
# False

# %%
print("x ="+x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-29cb74b288ef> in <module>
# ----> 1 print("x ="+x)
#
# TypeError: can only concatenate str (not "int") to str
